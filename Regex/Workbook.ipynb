# %%
import re

# %%
chat1 = 'you ask lot of questions  12345, abc@gmail.com (123)-456 my order # 345234'
chat2 = 'here it is: (123)-456, ab82_cDE@gmail.com my order number 345234'
chat3 = 'yes, phone: 123456 - email: abc@gmail.com my order 345234'

# %%
# Match phone nmumbers

# %%
pattern1 = '\d{6}$|\(\d{3}\)-\d{3}'
matches = re.findall(pattern1, chat1)
matches
# Out:
# ['(123)-456', '345234']

# %%
# Match emails

# %%
pattern2 = '[A-Za-z_0-9]*@[a-z0-9A-Z]*\.[a-z]*'
matches = re.findall(pattern2, chat2)
matches
# Out:
# ['ab82_cDE@gmail.com']

# %%
# match order number

# %%
pattern3 = 'order[^\d]*(\d*)'
matches = re.findall(pattern3, chat1)
matches
# Out:
# ['345234']

# %% [markdown]
# ![Screenshot%202023-07-21%20at%2011.54.17.png](attachment:Screenshot%202023-07-21%20at%2011.54.17.png)
